# %%
using Plots
f(x, y) = 1-x-y^2
surface(-1:0.1:1,-1:0.1:1, f,colorbar=false, alpha=0.9 ,xlabel = "x", ylabel = "y", zlabel = "f(x,y)")

# %%
using Plots,LinearAlgebra
# plotlyjs()
A = [1,0,0]
B = [0,1,0]
C = [0,0,1] 
f(u,v) = A+(u/2 *(C-A)+(1-u)*(B-A))*v

us = vs = range(0, 1, length=25)

xs,ys,vs = [[pt[i] for pt in  f.(us, vs')] for i=1:3]

# xs, ys, zs = [[pt[i] for pt in f.(us, vs')] for i in 1:3]
surface(xs, ys, zs)



# g(s,t,θ) = [f(s,t)[1],norm(f(s,t),2)*cos(θ),norm(f(s,t),2)*sin(θ)]
# # s = t = 0:0.01:1
# # θ = 0:0.01:2π

# f(0.5,0.5)



# g(0.5,0.5,0.23)

# xs=[]
# ys=[]
# zs=[]
# for θ = 0:0.1:2π
#     Q = g(.5,.5,θ)
#     append!(xs,Q[1])
#     append!(ys,Q[2])
#     append!(zs,Q[3])
# end
